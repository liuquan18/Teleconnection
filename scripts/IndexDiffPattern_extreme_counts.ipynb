# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from pyparsing import line
import xarray as xr
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import scipy.stats as stats

# %% [markdown]
# my module load

# %%
import src.Teleconnection.spatial_pattern as ssp
import src.Teleconnection.pattern_statistic as sps
import src.Teleconnection.index_statistic as sis
import src.plots.eof_plots as sept
import src.Teleconnection.temporal_index as sti

# %%
import importlib
importlib.reload(sis)
importlib.reload(sti)
importlib.reload(ssp)
importlib.reload(sept)
importlib.reload(sps)
# Out:
# <module 'src.Teleconnection.pattern_statistic' from '/work/mh0033/m300883/3rdPanel/src/Teleconnection/pattern_statistic.py'>

# %% [markdown]
# # IndexDiffPattern data load

# %% [markdown]
# all periods

# %%
all_all_ind = xr.open_dataset('/work/mh0033/m300883/3rdPanel/data/indexDiffPattern/all_all_ind.nc').pc
all_first_ind = xr.open_dataset('/work/mh0033/m300883/3rdPanel/data/indexDiffPattern/all_first_ind.nc').pc
all_last_ind = xr.open_dataset('/work/mh0033/m300883/3rdPanel/data/indexDiffPattern/all_last_ind.nc').pc

all_all_dep = xr.open_dataset('/work/mh0033/m300883/3rdPanel/data/indexDiffPattern/all_all_dep.nc').pc
all_first_dep = xr.open_dataset('/work/mh0033/m300883/3rdPanel/data/indexDiffPattern/all_frist_dep.nc').pc
all_last_dep = xr.open_dataset('/work/mh0033/m300883/3rdPanel/data/indexDiffPattern/all_last_dep.nc').pc

# %% [markdown]
# # Extreme Counts

# %% [markdown]
# |period\pattern|ind_first|ind_last|ind_all|dep_first|dep_last|dep_all|
# |-----|----|----|----|-----|----|-----|
# |first 10|ind_fF|ind_fL|ind_fA|dep_fF|dep_fL|dep_fA|
# |last 10|ind_lF|ind_lL|ind_lA|dep_lF|dep_lL|deplA|

# %% [markdown]
# ## counts

# %% [markdown]
# independent

# %%
ind_first10_exc,ind_last10_exc = sis.extreme_count([all_all_ind,all_first_ind,all_last_ind])

# %% [markdown]
# dependent

# %%
dep_first10_exc,dep_last10_exc = sis.extreme_count([all_all_dep,all_first_dep,all_last_dep])

# %% [markdown]
# ## to dataframe

# %%
ind_extc = sis.extr_count_df(ind_first10_exc,ind_last10_exc)

# %%
dep_extc = sis.extr_count_df(dep_first10_exc,dep_last10_exc)

# %% [markdown]
# ## bar plots of single layer

# %% [markdown]
# ### all layers

# %%
sept.extreme_bar([ind_extc,dep_extc],mode = 'NAO',hlayer = 'all', ylim = 450)

# %%
sept.extreme_bar([ind_extc,dep_extc],mode = 'EA',hlayer = 'all', ylim = 450)

# %% [markdown]
# ### Z200

# %%
sept.extreme_bar([ind_extc,dep_extc],mode = 'NAO',hlayer = 20000, ylim = 50)
# Out:
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]

# %%
sept.extreme_bar([ind_extc,dep_extc],mode = 'EA',hlayer = 20000, ylim = 50)
# Out:
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]

# %% [markdown]
# ### Z1000

# %%
sept.extreme_bar([ind_extc,dep_extc],mode = 'NAO',hlayer = 100000, ylim = 50)
# Out:
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]

# %%
sept.extreme_bar([ind_extc,dep_extc],mode = 'EA',hlayer = 100000, ylim = 50)
# Out:
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]
# /work/mh0033/m300883/3rdPanel/scripts/../src/eof_plots.py:351: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data = extreme_counts[j].loc[extr_type[i],mode,hlayer]

# %% [markdown]
# ## plots of vertical profile

# %%
sept.vertical_profile(ind_extc,mode = 'NAO')

# %%
sept.vertical_profile(dep_extc,mode = 'NAO')

# %%
sept.vertical_profile(ind_extc,mode = 'EA')

# %%
sept.vertical_profile(dep_extc,mode = 'EA')

# %% [markdown]
# ## compare

# %%
sept.vertical_profile_diff(ind_extc,dep_extc)

# %%
sept.vertical_profile_diff(ind_extc,dep_extc)

# %%
ind_extc.to_csv("/work/mh0033/m300883/3rdPanel/data/extreme_counts/ind_extc.csv")
dep_extc.to_csv("/work/mh0033/m300883/3rdPanel/data/extreme_counts/dep_extc.csv")

# %% [markdown]
# # for slides

# %%
sept.vertical_profile_slides(ind_extc,mode = 'NAO')

# %%
sept.vertical_profile_slides(dep_extc,mode = 'NAO')

# %%
sept.vertical_profile_slides(ind_extc,mode = 'EA')

# %%
sept.vertical_profile_slides(dep_extc,mode = 'EA')
