# %%
import xarray as xr
import src.Teleconnection.tools as tools
import src.composite.field_composite as composite

# %%
import numpy as np
import matplotlib.pyplot as plt
import proplot as pplt
import cartopy.crs as ccrs

# %%
import src.plots.utils as utils
import matplotlib as mpl
import src.plots.composite_spatial_pattern as composite_plots

# %% [markdown]
# # Read Data

# %% [markdown]
# The data to be averaged

# %%
# %%
print("reading data...")
# data
allens = xr.open_dataset(
    "/work/mh0033/m300883/transition/gr19/gphSeason/allens_season_time.nc"
)
# split ens
splitens = tools.split_ens(allens)

# demean ens-mean
demean = splitens - splitens.mean(dim="ens")

# select traposphere
trop = demean.sel(hlayers=slice(20000, 100000))

trop = trop.var156
# Out:
# reading data...

# %% [markdown]
# ## Pre-process the field data

# %% [markdown]
# standardize

# %%
trop = tools.standardize(trop)

# %% [markdown]
# ## The index as the conditions

# %%
first_index = xr.open_dataset("/work/mh0033/m300883/3rdPanel/data/allPattern/dep/all_pattern/first10_all_whole.nc").pc

# %%
last_index = xr.open_dataset("/work/mh0033/m300883/3rdPanel/data/allPattern/dep/all_pattern/last10_all_whole.nc").pc

# %% [markdown]
# ## Composite

# %%
first_sptial_pattern = composite.Tel_field_composite(first_index,trop)

# %%
last_sptial_pattern = composite.Tel_field_composite(last_index,trop)

# %% [markdown]
# ## show spatial maps

# %%
composite_plots.composite_gph(first_sptial_pattern, last_sptial_pattern, levels = np.arange(-3,3.1,0.5), hlayers=100000)
# Out:
# /home/m/m300883/miniconda3/envs/thirdPanel/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1614: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   result = super().contour(*args, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /work/mh0033/m300883/3rdPanel/scripts/first10_last10_index/fixed_pattern/composite_spatial_pattern.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blevante.dkrz.de/work/mh0033/m300883/3rdPanel/scripts/first10_last10_index/fixed_pattern/composite_spatial_pattern.ipynb#ch0000016vscode-remote?line=0'>1</a> composite_plots.composite_gph(first_sptial_pattern, last_sptial_pattern, levels = np.arange(-3,3.1,0.5), hlayers=100000)
#
# File /work/mh0033/m300883/3rdPanel/src/plots/composite_spatial_pattern.py:61, in composite_gph(first, last, levels, hlayers)
#      59         col.set_title(f"{modes[j]}  {extr_type[i]}")
#      60         utils.buildax(col, alpha_grid=0.3, alpha_coast=0.3)
# ---> 61         col.clabel(col,col.levels[::2])
#      62 fig.subplots_adjust(hspace=0.3, wspace=0.1, right=0.8)
#      63 cbar_ax = fig.add_axes([0.85, 0.25, 0.03, 0.5])
#
# AttributeError: 'GeoAxesSubplot' object has no attribute 'levels'

# %%
composite_plots.composite_gph(first_sptial_pattern, last_sptial_pattern, levels = np.arange(-3,3.1,0.5), hlayers=50000)
# Out:
# /home/m/m300883/miniconda3/envs/thirdPanel/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1614: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   result = super().contour(*args, **kwargs)
# /home/m/m300883/miniconda3/envs/thirdPanel/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1614: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   result = super().contour(*args, **kwargs)
# /home/m/m300883/miniconda3/envs/thirdPanel/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1614: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   result = super().contour(*args, **kwargs)
# /home/m/m300883/miniconda3/envs/thirdPanel/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1614: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   result = super().contour(*args, **kwargs)

# %% [markdown]
# # Vertical section

# %%
import src.Teleconnection.pattern_statistic as pattern_stat

# %%
first_sptial_pattern
# Out:
# <xarray.DataArray 'var156' (hlayers: 11, mode: 2, extr_type: 2, lat: 32, lon: 70)>
# array([[[[[-1.61774313e+00, -1.64082468e+00, -1.66332245e+00, ...,
#            -7.86043406e-01, -7.70119786e-01, -7.56163895e-01],
#           [-1.65660572e+00, -1.68566597e+00, -1.71412110e+00, ...,
#            -6.21412456e-01, -6.03572369e-01, -5.88465154e-01],
#           [-1.67460644e+00, -1.70999229e+00, -1.74451613e+00, ...,
#            -4.39950973e-01, -4.21431839e-01, -4.06363308e-01],
#           ...,
#           [ 9.52233493e-01,  9.19618428e-01,  8.84475350e-01, ...,
#             1.32896960e-01,  1.45403877e-01,  1.60192400e-01],
#           [ 7.87879586e-01,  7.47246385e-01,  7.05747247e-01, ...,
#             2.39816815e-01,  2.57186025e-01,  2.75740534e-01],
#           [ 5.81114590e-01,  5.37780166e-01,  4.93838072e-01, ...,
#             3.19784969e-01,  3.40698332e-01,  3.61219585e-01]],
#
#          [[ 1.20032883e+00,  1.21912956e+00,  1.23710644e+00, ...,
#             5.79018056e-01,  5.73377371e-01,  5.69137514e-01],
#           [ 1.26853764e+00,  1.29146373e+00,  1.31326842e+00, ...,
#             4.75060672e-01,  4.68056381e-01,  4.62988734e-01],
#           [ 1.32921219e+00,  1.35605216e+00,  1.38150954e+00, ...,
#             3.68487388e-01,  3.60516429e-01,  3.54887992e-01],
# ...
#             1.07952237e+00,  1.17410612e+00,  1.25926268e+00],
#           [-3.46908212e-01, -3.75207990e-01, -4.06668335e-01, ...,
#             1.03228068e+00,  1.10212469e+00,  1.19505131e+00],
#           [-3.56499583e-01, -3.77248347e-01, -3.97009790e-01, ...,
#             1.11776519e+00,  1.16728020e+00,  1.22391868e+00]],
#
#          [[-4.34387475e-01, -4.31704193e-01, -4.28443342e-01, ...,
#            -5.36218226e-01, -5.37170410e-01, -5.38353622e-01],
#           [-4.45340186e-01, -4.41354096e-01, -4.35427189e-01, ...,
#            -4.60286766e-01, -4.63524073e-01, -4.66547400e-01],
#           [-4.64249313e-01, -4.61413532e-01, -4.55172956e-01, ...,
#            -3.59570563e-01, -3.65752697e-01, -3.71322781e-01],
#           ...,
#           [ 1.23188093e-01,  2.14506209e-01,  2.87555844e-01, ...,
#            -1.23306084e+00, -1.33164597e+00, -1.43675339e+00],
#           [ 1.22795835e-01,  2.01638177e-01,  2.74281800e-01, ...,
#            -1.14328146e+00, -1.21512365e+00, -1.29123664e+00],
#           [ 1.10892773e-01,  1.80919901e-01,  2.39621565e-01, ...,
#            -1.15436769e+00, -1.20644784e+00, -1.25166500e+00]]]]],
#       dtype=float32)
# Coordinates:
#   * lon        (lon) float64 -90.0 -88.12 -86.25 -84.38 ... 35.62 37.5 39.38
#   * lat        (lat) float64 79.27 77.41 75.54 73.68 ... 27.05 25.18 23.32 21.45
#   * hlayers    (hlayers) float64 2e+04 2.5e+04 3e+04 ... 8.5e+04 9.25e+04 1e+05
#   * mode       (mode) object 'NAO' 'EA'
#   * extr_type  (extr_type) <U3 'pos' 'neg'

# %%
first_NAO_lat_height = pattern_stat.lat_height(first_sptial_pattern,mode = 'NAO')
last_NAO_lat_height = pattern_stat.lat_height(last_sptial_pattern,mode = 'NAO')

# %%
first_EA_lon_height = pattern_stat.lon_height(first_sptial_pattern,mode = 'EA')
last_EA_lon_height = pattern_stat.lon_height(last_sptial_pattern,mode = 'EA')

# %%
fig, axes = pplt.subplots(nrows=2, ncols=2, wspace=2, hspace=2, sharex=False)
axes.format(
    abc="a",
    abcloc="ul",
    xminorlocator="null",
    yminorlocator="null",
    suptitle=f"spatial pattern change",
    yreverse=True,
    xreverse=False,
    toplabels=("meridional NAO", "horizontal EA"),
    leftlabels=("pos", "neg"),
)

# first10 years contourf
first_data_all =[first_NAO_lat_height.sel(extr_type = 'pos'),
                first_EA_lon_height.sel(extr_type = 'pos'),
                first_NAO_lat_height.sel(extr_type = 'neg'),
                first_EA_lon_height.sel(extr_type = 'neg')]

# last10 years
last_data_all =[last_NAO_lat_height.sel(extr_type = 'pos'),
                last_EA_lon_height.sel(extr_type = 'pos'),
                last_NAO_lat_height.sel(extr_type = 'neg'),
                last_EA_lon_height.sel(extr_type = 'neg')]

levels = [np.arange(-1.8, 1.9, 0.3),
          np.arange(-0.8, 0.9, 0.1),
          np.arange(-1.8, 1.9, 0.3),
          np.arange(-0.8, 0.9, 0.1),
        ]
shadings = []
lines = []
for ax, first_data, last_data,level in zip(axes,first_data_all, last_data_all,levels):
    # 
    shading = ax.contourf(
    first_data,
    x="lat",
    y="hlayers",
    levels=level,
    extend="both",
    )

    line = ax.contour(
    last_data,
    x="lat",
    y="hlayers",
    levels=level,
    extend="both",
    colors="k",
    color='gray8',
)
    ax.clabel(line,line.levels[::2])

    shadings.append(shading)
    lines.append(line)
    

axes[1, 0].format(xlabel="latittude")
axes[1, 1].format(xlabel="longitude")

axes[1, 0].colorbar(shadings[0], loc="b", label="NAO/std")
axes[1, 1].colorbar(shadings[1], loc="b", label="EA/std")
# Out:
# /tmp/ipykernel_4125597/3502192689.py:35: ProplotWarning: Got conflicting or duplicate keyword args: {'x_positional': <xarray.DataArray 'var156' (hlayers: 11, lat: 32)>
# array([[-1.5275282 , -1.5531045 , -1.560409  , -1.5465964 , -1.5085455 ,
#         -1.4450177 , -1.3548781 , -1.2380632 , -1.0964793 , -0.9306829 ,
#         -0.7414651 , -0.5321634 , -0.30507547, -0.06180647,  0.19526546,
#          0.45902726,  0.70985025,  0.918969  ,  1.0654666 ,  1.1446387 ,
#          1.1640108 ,  1.1343347 ,  1.0644054 ,  0.9594525 ,  0.82293284,
#          0.6597792 ,  0.478536  ,  0.29369843,  0.12161673, -0.02302729,
#         -0.1309828 , -0.19805153],
#        [-1.4251105 , -1.4775695 , -1.5117074 , -1.5222493 , -1.5058736 ,
#         -1.4607536 , -1.3858489 , -1.2850174 , -1.1565901 , -1.0016546 ,
#         -0.82058483, -0.6169679 , -0.39392957, -0.15332815,  0.10336123,
#          0.37012422,  0.6275515 ,  0.84577036,  1.0015756 ,  1.0876479 ,
#          1.1106169 ,  1.0835422 ,  1.0173707 ,  0.91687816,  0.78893936,
#          0.6389286 ,  0.47390202,  0.3065817 ,  0.14862269,  0.01116323,
#        [ 1.3802459 ,  1.4092485 ,  1.4245449 ,  1.4256777 ,  1.4134396 ,
#          1.3859985 ,  1.3370773 ,  1.2647787 ,  1.1666019 ,  1.0402979 ,
#          0.882302  ,  0.6920109 ,  0.46872216,  0.21479504, -0.06458304,
#         -0.3606907 , -0.65390146, -0.91249424, -1.1083533 , -1.2312323 ,
#         -1.2843173 , -1.2755405 , -1.2102219 , -1.089595  , -0.9200371 ,
#         -0.7111524 , -0.4775109 , -0.24084707, -0.02186123,  0.16519885,
#          0.31564683,  0.4281915 ],
#        [ 1.3334302 ,  1.3701116 ,  1.3927593 ,  1.4013906 ,  1.396943  ,
#          1.3770325 ,  1.3364154 ,  1.270652  ,  1.1796232 ,  1.0609137 ,
#          0.91153026,  0.72971565,  0.5147524 ,  0.26823732, -0.00461298,
#         -0.2957351 , -0.58759165, -0.84976995, -1.0536062 , -1.1862028 ,
#         -1.2500087 , -1.2521758 , -1.1977535 , -1.0910989 , -0.93613446,
#         -0.7419188 , -0.52224815, -0.2933147 , -0.07305629,  0.12093653,
# ...
#          1.7448545 ,  1.6824085 ,  1.5962714 ,  1.482851  ,  1.3356961 ,
#          1.1422756 ,  0.8916161 ,  0.5863759 ,  0.24540582, -0.10999284,
#         -0.46204016, -0.7863664 , -1.0611103 , -1.2765073 , -1.4292796 ,
#         -1.5226032 , -1.5671505 , -1.5630932 , -1.5327264 , -1.4895313 ,
#         -1.4340473 , -1.358834  , -1.2665468 , -1.155768  , -1.0283566 ,
#         -0.8955398 , -0.74830705],
#        [ 1.8418734 ,  1.8474852 ,  1.84983   ,  1.8336256 ,  1.8043187 ,
#          1.7642764 ,  1.703666  ,  1.6193004 ,  1.5080038 ,  1.3623246 ,
#          1.1650333 ,  0.9010077 ,  0.57433474,  0.20902522, -0.16780509,
#         -0.526627  , -0.8435848 , -1.1095636 , -1.3199254 , -1.4714565 ,
#         -1.5676334 , -1.6140141 , -1.6168946 , -1.5957185 , -1.5681684 ,
#         -1.5302019 , -1.4778218 , -1.4105446 , -1.3228303 , -1.2189522 ,
#         -1.112184  , -0.99885637],
#        [ 1.8543854 ,  1.8520066 ,  1.8530773 ,  1.8335437 ,  1.8017436 ,
#          1.7625502 ,  1.7031143 ,  1.6226171 ,  1.5176926 ,  1.3761367 ,
#          1.1767108 ,  0.90412444,  0.5605021 ,  0.17564014, -0.21217914,
#         -0.5644895 , -0.8650779 , -1.118232  , -1.3211703 , -1.4735562 ,
#         -1.5744243 , -1.6253414 , -1.6336007 , -1.6188921 , -1.5995456 ,
#         -1.5677972 , -1.5230554 , -1.4635777 , -1.382373  , -1.2878773 ,
#         -1.1923572 , -1.0905799 ]], dtype=float32)
# Coordinates:
#   * lat        (lat) float64 79.27 77.41 75.54 73.68 ... 27.05 25.18 23.32 21.45
#   * hlayers    (hlayers) float64 200.0 250.0 300.0 400.0 ... 850.0 925.0 1e+03
#     mode       <U3 'NAO'
#     extr_type  <U3 'neg', 'x': 'lat'}. Using the first one.
#   line = ax.contour(
# /tmp/ipykernel_4125597/3502192689.py:43: ProplotWarning: Got conflicting or duplicate keyword args: {'colors': 'k', 'color': 'gray8'}. Using the first one.
#   line = ax.contour(
# /tmp/ipykernel_4125597/3502192689.py:35: ProplotWarning: Got conflicting or duplicate keyword args: {'x_positional': <xarray.DataArray 'var156' (hlayers: 11, lon: 69)>
# array([[-0.2905351 , -0.29426244, -0.2976883 , -0.30071244, -0.30311966,
#         -0.30454743, -0.30494305, -0.30412236, -0.30184367, -0.29763475,
#         -0.2908025 , -0.28064448, -0.26660153, -0.24808761, -0.22430979,
#         -0.1948298 , -0.16003685, -0.12048578, -0.07691485, -0.03033171,
#          0.01777604,  0.06581715,  0.1124596 ,  0.15703791,  0.19910839,
#          0.23837093,  0.27424276,  0.30604842,  0.33332247,  0.35574067,
#          0.37310854,  0.3854428 ,  0.39316717,  0.3963423 ,  0.3947903 ,
#          0.38871494,  0.37849542,  0.3644601 ,  0.34645444,  0.32486758,
#          0.30060938,  0.27422747,  0.24537827,  0.21338962,  0.17822017,
#          0.14078425,  0.10195438,  0.06175099,  0.0198752 , -0.02372755,
#         -0.06870345, -0.11437572, -0.15999791, -0.20503052, -0.24909936,
#         -0.29155836, -0.33162364, -0.36865517, -0.4019357 , -0.43033767,
#         -0.45287022, -0.46963486, -0.48103008, -0.48718563, -0.48795924,
#         -0.48368886, -0.47456264, -0.46093068, -0.44369665],
#        [-0.25617445, -0.25941187, -0.2629622 , -0.26660866, -0.2702327 ,
#         -0.27344468, -0.27582836, -0.2768016 , -0.27635866, -0.27401596,
#         -0.2691641 , -0.26105663, -0.24908431, -0.23254195, -0.2106745 ,
#         -0.18256295, -0.14839827, -0.109033  , -0.06564226, -0.01954785,
#          0.02765936,  0.07476432,  0.12063424,  0.16489679,  0.20686455,
#          0.24616171,  0.28186864,  0.3133083 ,  0.34022748,  0.3618472 ,
# ...
#          0.30660602,  0.28995073,  0.2646889 ,  0.23607586,  0.20561947,
#          0.17323916,  0.13992912,  0.10620969,  0.06998974,  0.02992398,
#         -0.01258113, -0.05834024, -0.10550629, -0.149047  , -0.1858351 ,
#         -0.21859305, -0.25484598, -0.29391226, -0.3330111 , -0.36767986,
#         -0.39820465, -0.4253489 , -0.448674  , -0.4646998 ],
#        [-0.37808686, -0.35111794, -0.32209194, -0.29582578, -0.26996034,
#         -0.24173592, -0.21415272, -0.19042523, -0.16930294, -0.15102856,
#         -0.13515769, -0.11981573, -0.1028906 , -0.08222038, -0.05459974,
#         -0.01974686,  0.01869195,  0.05918552,  0.10260929,  0.14651525,
#          0.18613806,  0.2212957 ,  0.25158077,  0.27724537,  0.30202904,
#          0.32663274,  0.35030782,  0.37411484,  0.3971107 ,  0.41716075,
#          0.43359482,  0.44756907,  0.46180072,  0.4764101 ,  0.48774508,
#          0.49361318,  0.49394345,  0.4877294 ,  0.474021  ,  0.45487943,
#          0.43415913,  0.4112042 ,  0.38647094,  0.3684625 ,  0.36515862,
#          0.36493438,  0.35394767,  0.3327993 ,  0.30696464,  0.27836543,
#          0.24705842,  0.21478474,  0.18272144,  0.14978679,  0.11351057,
#          0.07292124,  0.0286551 , -0.01670313, -0.05661463, -0.0881244 ,
#         -0.11734247, -0.15032718, -0.19010869, -0.23112394, -0.26869294,
#         -0.3024238 , -0.33330628, -0.361069  , -0.38401553]],
#       dtype=float32)
# Coordinates:
#   * lon        (lon) float64 -88.12 -86.25 -84.38 -82.5 ... 35.62 37.5 39.38
#   * hlayers    (hlayers) float64 200.0 250.0 300.0 400.0 ... 850.0 925.0 1e+03
#     mode       <U2 'EA'
#     extr_type  <U3 'neg', 'x': 'lat'}. Using the first one.
#   shading = ax.contourf(
# /tmp/ipykernel_4125597/3502192689.py:43: ProplotWarning: Got conflicting or duplicate keyword args: {'x_positional': <xarray.DataArray 'var156' (hlayers: 11, lon: 69)>
# array([[-9.86459702e-02, -9.57214534e-02, -9.37628150e-02,
#         -9.22789723e-02, -9.08712819e-02, -8.95204246e-02,
#         -8.83551911e-02, -8.71311203e-02, -8.54777321e-02,
#         -8.33567753e-02, -8.06042030e-02, -7.67112672e-02,
#         -7.14320242e-02, -6.47205710e-02, -5.61305992e-02,
#         -4.50522229e-02, -3.13322507e-02, -1.51594020e-02,
#          3.57347936e-03,  2.48966441e-02,  4.84217219e-02,
#          7.36599341e-02,  1.00017793e-01,  1.27212048e-01,
#          1.55054629e-01,  1.83165193e-01,  2.10830912e-01,
#          2.37331867e-01,  2.62376428e-01,  2.85643876e-01,
#          3.06603789e-01,  3.25230390e-01,  3.41570526e-01,
#          3.54918510e-01,  3.64301264e-01,  3.69456857e-01,
#          3.70199442e-01,  3.66235286e-01,  3.57280731e-01,
#          3.43245834e-01,  3.24340433e-01,  3.00906688e-01,
#          2.72738695e-01,  2.38750324e-01,  1.99446589e-01,
#          1.56332225e-01,  1.11552045e-01,  6.61850423e-02,
#          2.02092770e-02, -2.62244232e-02, -7.23217130e-02,
#         -1.17101580e-01, -1.59920618e-01, -2.00179592e-01,
#         -2.37400532e-01, -2.71466792e-01, -3.02468270e-01,
#         -3.30565125e-01, -3.56178552e-01, -3.79337370e-01,
# ...
#         -9.43825170e-02, -6.72063455e-02, -4.02350128e-02,
#         -1.29103241e-02,  1.38819497e-02,  4.01615389e-02,
#          6.76689446e-02,  9.75277722e-02,  1.28400639e-01,
#          1.58778608e-01,  1.86124399e-01,  2.07539901e-01,
#          2.23672256e-01,  2.38183767e-01,  2.52786458e-01,
#          2.68677294e-01,  2.86131710e-01,  3.06040019e-01,
#          3.27866971e-01,  3.50876093e-01,  3.72264683e-01,
#          3.90342683e-01,  4.06941622e-01,  4.24587518e-01,
#          4.43379611e-01,  4.61414486e-01,  4.78221089e-01,
#          4.92729753e-01,  5.02665281e-01,  5.07259727e-01,
#          5.09184361e-01,  5.10460913e-01,  5.09375513e-01,
#          5.03756702e-01,  4.99408334e-01,  5.05537271e-01,
#          5.13720334e-01,  5.11290312e-01,  4.97953296e-01,
#          4.77407515e-01,  4.53143686e-01,  4.26410109e-01,
#          3.96962672e-01,  3.64382803e-01,  3.28772336e-01,
#          2.91026086e-01,  2.50727117e-01,  2.09295720e-01,
#          1.69708535e-01,  1.36322394e-01,  1.09465614e-01,
#          8.42031538e-02,  5.61606847e-02,  2.47382354e-02,
#         -4.68949042e-03, -2.77072806e-02, -4.82613705e-02,
#         -6.90866783e-02, -8.97055939e-02, -1.07888222e-01]], dtype=float32)
# Coordinates:
#   * lon        (lon) float64 -88.12 -86.25 -84.38 -82.5 ... 35.62 37.5 39.38
#   * hlayers    (hlayers) float64 200.0 250.0 300.0 400.0 ... 850.0 925.0 1e+03
#     mode       <U2 'EA'
#     extr_type  <U3 'neg', 'x': 'lat'}. Using the first one.
#   line = ax.contour(
# /tmp/ipykernel_4125597/3502192689.py:43: ProplotWarning: Got conflicting or duplicate keyword args: {'colors': 'k', 'color': 'gray8'}. Using the first one.
#   line = ax.contour(
# Figure(nrows=2, ncols=2, refwidth=2.5)
